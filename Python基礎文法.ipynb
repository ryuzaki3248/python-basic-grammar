# %% [markdown]
# <a href="https://colab.research.google.com/github/ryuzaki3248/python-basic-grammar/blob/main/Python%E5%9F%BA%E7%A4%8E%E6%96%87%E6%B3%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
# Out:
# Hello World

# %%
# これはHello Worldと表示するプログラムです
print("Hello World")

# これはコメントアウトされるため何も処理を行いません
# print("こんにちは世界")
# Out:
# Hello World

# %%
#↓ここに全角スペースがある
　print("Hello World")
# Out:
#   File "<ipython-input-9-c3588ea1c3c2>", line 2
#     print("Hello World")
#     ^
# SyntaxError: invalid non-printable character U+3000

# %%
# 「prnt」になってしまっている
prnt ("Hello World")

# %%
# 文字列を連結する
"Hello " + "World"
# Out:
# 'Hello World'

# %%
# 文字列を連結
"Hey!" + " brother!"
# Out:
# 'Hey! brother!'

# %%
# 文字列の文字数を出す
len("Hello World")
# Out:
# 11

# %%
# 整数
10

# 負の値
-10

# 小数
3.14
# Out:
# 3.14

# %%
# 数値を書いてエンターキーで実行
12345
# Out:
# 12345

# %%
# 数値を書いてエンターキーで実行
12345
# Out:
# 12345

# %%
# 足し算
1000 + 2000
# →3000と出力される

# 引き算
3000 - 1500
# →1500と出力される

# 掛け算
50 * 40
# →2000と出力される

# 割り算
600 / 15
# →40と出力される

# 剰余演算（5 ÷ 2をした余り）
5 % 2
# →1と出力される
# Out:
# 1

# %%
24 * 365
# Out:
# 8760

# %%
# 文字列と数値を連結させようとするとエラーが発生
"i am " + 20 + " years old."
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-f2721f58c227> in <cell line: 2>()
#       1 # 文字列と数値を連結させようとするとエラーが発生
# ----> 2 "i am " + 20 + " years old."
#
# TypeError: can only concatenate str (not "int") to str

# %%
# str関数で数値を文字列に変換
str(20)
# Out:
# '20'

# %% [markdown]
# # str関数で数値を文字列に変換し、連結
# "i am " + str(20) + " years old."

# %%
# int関数で文字列を数値に変換
int("100") + 400
# Out:
# 500

# %%
# f文字列を使って、文字列に式を埋め込む
 f"今日で{19 + 1}歳になりました"
# Out:
#   File "<ipython-input-14-99d8f38c6efb>", line 2
#     f"今日で{19 + 1}歳になりました"
#     ^
# IndentationError: unexpected indent

# %%
 f"今日で{19 + 1}歳になりました"
# Out:
# '今日で20歳になりました'

# %%
# f文字列を使って、文字列に式を埋め込む
f"今日で{19 + 1}歳になりました"
# Out:
# '今日で20歳になりました'

# %%
"ようこそ！名前を入力してください"

"秒数を知りたい時間を分単位で入力してください"

f"タロウさん、{5}分は{5 * 60}秒です！"
# Out:
# 'タロウさん、5分は300秒です！'

# %% [markdown]
# 12345

# %%
12345
# Out:
# 12345

# %%
# 足し算
1000 + 2000
# →3000と出力される

# 引き算
3000 - 1500
# →1500と出力される

# 掛け算
50 * 40
# →2000と出力される

# 割り算
600 / 15
# →40と出力される

# 剰余演算（5 ÷ 2をした余り）
5 % 2
# →1と出力される
# Out:
# 1

# %%
"ようこそ！名前を入力してください"

"秒数を知りたい時間を分単位で入力してください"

f"タロウさん、{5}分は{5 * 60}秒です！"
# Out:
# 'タロウさん、5分は300秒です！'

# %%
# 半径3の円の面積
3 * 3 * 3.14159

# 半径10の円の面積
10 * 10 * 3.14159

# 半径11の円の面積
11 * 11 * 3.14159
# Out:
# 380.13239

# %%
# piという変数の中身を、円周率の3.14159であると定義する
pi = 3.14159

# piの内容を表示させると、格納された3.14159が出力される
print(pi)
# →3.14159

# 何度実行しても、同じ結果が出力される
print(pi)
# →3.14159
# Out:
# 3.14159
# 3.14159

# %%
name = "Taro"

# %%
# 画面に出力する
print(name)
# Out:
# Taro

# %%
# 変数に代入
value = "Hello World"

# 変数を出力
print(value)

# → 'Hello World'

# 変数に再代入
value = "See you"

# 変数を出力
print(value)

# →'See you'
# Out:
# Hello World
# See you

# %%
number = number + 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-8510cca14c26> in <cell line: 1>()
# ----> 1 number = number + 1
#
# NameError: name 'number' is not defined

# %%
# 変数に代入
title = "Spider man"

# 変数に代入
description = "It is amazing"

# 変数を出力
print(title)

# → ‘Spider man’

# 変数を出力
print(description)

# → ‘It is amazing’
# Out:
# Spider man
# It is amazing

# %%
# 直径10の場合
menseki = (10 / 2) * (10 / 2) * 3.14  # 面積
print(menseki)

# → 78.5

ensyu = 10 * 3.14  # 円周
print(ensyu)

# → 31.400000000000002
# Out:
# 78.5
# 31.400000000000002

# %%
# 変数に値を代入
name = "takashi"

# 文字数を調べる
name_length = len(name)
print(name_length)

# → 7

# 変数を出力
print(name)

# → 'takashi'
# Out:
# 7
# takashi

# %%
"ようこそ！名前を入力してください"
name = "タロウ"

"秒数を知りたい時間を分単位で入力してください"
minutes = 5

f"{name}さん、{minutes}分は{minutes * 60}秒です！"
# Out:
# 'タロウさん、5分は300秒です！'

# %% [markdown]
# "ようこそ！名前を入力してください"
# name = "タロウ"
#
# "秒数を知りたい時間を分単位で入力してください"
# minutes = 5
#
# f"{name}さん、{minutes}分は{minutes * 60}秒です！"

# %%
name = "タロウ"
minutes = 5
seconds_in_a_minute = 60

# 分を秒に変換
seconds = minutes * seconds_in_a_minute

# 文字列をフォーマットして表示
print(f"{name}さん、{minutes}分は{seconds}秒です！")
# Out:
# タロウさん、5分は300秒です！

# %%
# 入力機能が起動、入力された値が文字列として返る
name = input()

print(name)
# Out:
# Hello World
# Hello World

# %%
text = input()

print(f"入力した値は{text}です")
# Out:
# Hello World
# 入力した値はHello Worldです

# %%
\n
# Out:
#   File "<ipython-input-19-d4a7e95adeab>", line 1
#     \n
#      ^
# SyntaxError: unexpected character after line continuation character

# %%
text = input()

print(f"入力した値は{text}です")
print(f"入力した値は{text}です\n")
print(f"入力した値は{text}です")
# Out:
# Python
# 入力した値はPythonです
# 入力した値はPythonです
#
# 入力した値はPythonです

# %%
print("ようこそ！名前を入力してください")
name = "タロウ"

print("秒数を知りたい時間を分単位で入力してください")
minutes = 5
seconds = minutes * 60

print(f"{name}さん、{minutes}分は{seconds}秒です！")
# Out:
# ようこそ！名前を入力してください
# 秒数を知りたい時間を分単位で入力してください
# タロウさん、5分は300秒です！

# %%
print("ようこそ！\n名前を入力してください")
name = "タロウ"

print("秒数を知りたい時間を分単位で入力してください")
minutes = 5
seconds = minutes * 60

print(f"{name}さん、{minutes}分は{seconds}秒です！")
# Out:
# ようこそ！
# 名前を入力してください
# 秒数を知りたい時間を分単位で入力してください
# タロウさん、5分は300秒です！

# %%
print("ようこそ！\n名前を入力してください")
name = "タロウ"

print("秒数を知りたい時間を分単位で入力してください")
minutes = 5
seconds = minutes * 60

print(f"{name}さん、{minutes}分は{seconds}秒です！")
# Out:
# ようこそ！
# 名前を入力してください
# 秒数を知りたい時間を分単位で入力してください
# タロウさん、5分は300秒です！

# %%
print("ようこそ！\n名前を入力してください")
name = input()

print("秒数を知りたい時間を分単位で入力してください")
minutes =  int(input())
seconds = minutes * 60

print(f"{name}さん、{minutes}分は{seconds}秒です！")
# Out:
# ようこそ！
# 名前を入力してください
# ああ
# 秒数を知りたい時間を分単位で入力してください
# 5
# ああさん、5分は300秒です！

# %%
pencil_case = ["ペン", "消しゴム", "定規"]

print(pencil_case)
# Out:
# ['ペン', '消しゴム', '定規']

# %%
pencil_case = ["ペン", "消しゴム", "定規"]
pencil_case.append("えんぴつ")

print(pencil_case)
# Out:
# ['ペン', '消しゴム', '定規', 'えんぴつ']

# %%
pencil_case = ["ペン", "消しゴム", "定規"]
pencil_case.append("えんぴつ")

print(pencil_case)
print(pencil_case[1])
# Out:
# ['ペン', '消しゴム', '定規', 'えんぴつ']
# 消しゴム

# %%
pencil_case = ["ペン", "消しゴム", "定規"]
pencil_case.append("えんぴつ")
pencil_case[1] = "修正ペン"

print(pencil_case)
print(pencil_case[1])
# Out:
# ['ペン', '修正ペン', '定規', 'えんぴつ']
# 修正ペン

# %%
len(['あお', 'きいろ', 'あか'])
# Out:
# 3

# %%
pencil_case = ["ペン", "消しゴム", "定規"]
print(len(pencil_case))

pencil_case.append("えんぴつ")
pencil_case.append("付箋")
print(len(pencil_case))
# Out:
# 3
# 5

# %%
ride_count = 0
friends = []

print("お友達の名前は？")
friends.append(input())
print("お友達の身長は？")
friends.append(int(input()))
ride_count += 1

print("お友達の名前は？")
friends.append(input())
print("お友達の身長は？")
friends.append(int(input()))
ride_count += 1

print("お友達の名前は？")
friends.append(input())
print("お友達の身長は？")
friends.append(int(input()))
ride_count += 1

print(f"乗車するのは{ride_count}人です")
# Out:
# お友達の名前は？
# ケン
# お友達の身長は？
# 150
# お友達の名前は？
# マイケル
# お友達の身長は？
# １４０
# お友達の名前は？
# りさ
# お友達の身長は？
# １３０
# 乗車するのは3人です

# %%
student = {"name":  "John", "age": 10 }
teacher = {"name": "Mike", "age": 25 }

print(student)
print(teacher)
# Out:
# {'name': 'John', 'age': 10}
# {'name': 'Mike', 'age': 25}

# %%
student = {"name":  "John", "age": 10 }
teacher = {"name": "Mike", "age": 25 }

teacher["subject"] = "English"

print(student)
print(teacher)
# Out:
# {'name': 'John', 'age': 10}
# {'name': 'Mike', 'age': 25, 'subject': 'English'}

# %%
student = {"name":  "John", "age": 10 }
teacher = {"name": "Mike", "age": 25 }

teacher["subject"] = "English"


print(student)
print(teacher)
print(teacher["name"])
# Out:
# {'name': 'John', 'age': 10}
# {'name': 'Mike', 'age': 25, 'subject': 'English'}
# Mike

# %%
student = {"name":  "John", "age": 10 }
teacher = {"name": "Mike", "age": 25 }

teacher["subject"] = "English"
teacher["name"] = "Emma"


print(student)
print(teacher)
print(teacher["name"])
# Out:
# {'name': 'John', 'age': 10}
# {'name': 'Emma', 'age': 25, 'subject': 'English'}
# Emma

# %%
ride_count = 0
friends = []

friend = {}
print("お友達の名前は？")
friend["name"] = input()
print("お友達の身長は？")
friend["height"] = int(input())
friends.append(friend)
ride_count += 1

friend = {}
print("お友達の名前は？")
friend["name"] = input()
print("お友達の身長は？")
friend["height"] = int(input())
friends.append(friend)
ride_count += 1

friend = {}
print("お友達の名前は？")
friend["name"] = input()
print("お友達の身長は？")
friend["height"] = int(input())
friends.append(friend)
ride_count += 1

print(f"乗車するのは{ride_count}人です")
# Out:
# お友達の名前は？
# ケン
# お友達の身長は？
# ０
# お友達の名前は？
# マイケル
# お友達の身長は？
# −１
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-8277879c1603> in <cell line: 16>()
#      14 friend["name"] = input()
#      15 print("お友達の身長は？")
# ---> 16 friend["height"] = int(input())
#      17 friends.append(friend)
#      18 ride_count += 1
#
# ValueError: invalid literal for int() with base 10: '−１'

# %%
ride_count = 0
friends = []

friend = {}
print("お友達の名前は？")
friend["name"] = input()
print("お友達の身長は？")
friend["height"] = int(input())
friends.append(friend)
ride_count += 1

friend = {}
print("お友達の名前は？")
friend["name"] = input()
print("お友達の身長は？")
friend["height"] = int(input())
friends.append(friend)
ride_count += 1

friend = {}
print("お友達の名前は？")
friend["name"] = input()
print("お友達の身長は？")
friend["height"] = int(input())
friends.append(friend)
ride_count += 1

print(f"乗車するのは{ride_count}人です")
# Out:
# お友達の名前は？
# けん
# お友達の身長は？
# ４
# お友達の名前は？
# マイケル
# お友達の身長は？
# ４
# お友達の名前は？
# ミケ
# お友達の身長は？
# ４
# 乗車するのは3人です

# %%
# 1は20より小さいか？
1 < 20
# → True

# 5は5以下か？
5 <= 5
# → True

# 1は20より大きいか？
1 > 20
# → False

# 5は5以上か？
5 >= 5
# → True

# 2 × 5は10と等しいか？
2 * 5 == 10
# → True

# 10は20と等しいか？
10 == 20
# → False
# Out:
# False

# %%
# 5は5以下か？
5 <= 5
# → True
# Out:
# True

# %%
print('東京タワーの高さはスカイツリー以下か？')
print(333 <= 634)

print('東京タワーの高さはスカイツリー以上か？')
print(333 >= 634)
# Out:
# 東京タワーの高さはスカイツリー以下か？
# True
# 東京タワーの高さはスカイツリー以上か？
# False

# %%
print('数値の777と文字列の"777"は異なるか？')
print(777 != "777")

print('文字列"海"と"海"は異なるか？')
print("海" != "海")
# Out:
# 数値の777と文字列の"777"は異なるか？
# True
# 文字列"海"と"海"は異なるか？
# False

# %%
value

if value > 0:
    print("値は正です")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-a34514ea861e> in <cell line: 1>()
# ----> 1 value
#       2
#       3 if value > 0:
#       4     print("値は正です")
#
# NameError: name 'value' is not defined

# %%
value = 3

if value > 0:
    print("値は正です")
# Out:
# 値は正です

# %%
value = 3

if value > 0:
print("値は正です")
# Out:
#   File "<ipython-input-13-104d3f18157b>", line 4
#     print("値は正です")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 3

# %%
value = 3

if value > 0:
  print("値は正です")
# Out:
# 値は正です

# %%
value = 3

if value > 0:
              print("値は正です")
# Out:
# 値は正です

# %%
value = -1

if value > 0:
    print("値は正です")
else:
    print ("値は負です")
# Out:
# 値は負です

# %%
value =int(input())

if value > 0:
    print("値は正です")
elif value < 0:
    print("値は負です")
else:
    print("値は0です")

# %%
ride_count = 0
friends = []

friend = {}
print("お友達の名前は？")
friend["name"] = input()
print("お友達の身長は？")
friend["height"] = int(input())
friends.append(friend)
if friend["height"] >= 130:
    print (f"{friend['name']}くんは乗車できます")
    ride_count += 1
else:
    print(f"{friend['name']}くんは乗車できません！")


friend = {}
print("お友達の名前は？")
friend["name"] = input()
print("お友達の身長は？")
friend["height"] = int(input())
friends.append(friend)
if friend["height"] >= 130:
    print (f"{friend['name']}くんは乗車できます")
    ride_count += 1
else:
    print(f"{friend['name']}くんは乗車できません！")


friend = {}
print("お友達の名前は？")
friend['name'] = input()
print("お友達の身長は？")
friend['height'] = int(input())
friends.append(friend)
if friend['height'] >= 130:
    print (f"{friend['name']}くんは乗車できます")
    ride_count += 1
else:
    print(f"{friend['name']}くんは乗車できません！")


print(f"乗車するのは{ride_count}人です")
# Out:
# お友達の名前は？
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-1304254bdbb3> in <cell line: 6>()
#       4 friend = {}
#       5 print("お友達の名前は？")
# ----> 6 friend["name"] = input()
#       7 print("お友達の身長は？")
#       8 friend["height"] = int(input())
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
colors = ["あか", "あお", "きいろ"]

print(f"色: {colors[0]}")
print(f"色: {colors[1]}")
print(f"色: {colors[2]}")
# Out:
# 色: あか
# 色: あお
# 色: きいろ

# %%
colors = ["あか", "あお", "きいろ"]

for color in colors:
    print(f"色: {color}")
# Out:
# 色: あか
# 色: あお
# 色: きいろ

# %%
colors = ["あか", "あお", "きいろ"]

for color in colors:
    print(color)
# Out:
# あか
# あお
# きいろ

# %%
colors = ["あか", "あお", "きいろ"]

for color in colors:
    print("色:", color)
# Out:
# 色: あか
# 色: あお
# 色: きいろ

# %%
for i in range(110000):
    print(i + 1)
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# 105001
# 105002
# 105003
# 105004
# 105005
# 105006
# 105007
# 105008
# 105009
# 105010
# 105011
# 105012
# 105013
# 105014
# 105015
# 105016
# 105017
# 105018
# 105019
# 105020
# 105021
# 105022
# 105023
# 105024
# 105025
# 105026
# 105027
# 105028
# 105029
# 105030
# 105031
# 105032
# 105033
# 105034
# 105035
# 105036
# 105037
# 105038
# 105039
# 105040
# 105041
# 105042
# 105043
# 105044
# 105045
# 105046
# 105047
# 105048
# 105049
# 105050
# 105051
# 105052
# 105053
# 105054
# 105055
# 105056
# 105057
# 105058
# 105059
# 105060
# 105061
# 105062
# 105063
# 105064
# 105065
# 105066
# 105067
# 105068
# 105069
# 105070
# 105071
# 105072
# 105073
# 105074
# 105075
# 105076
# 105077
# 105078
# 105079
# 105080
# 105081
# 105082
# 105083
# 105084
# 105085
# 105086
# 105087
# 105088
# 105089
# 105090
# 105091
# 105092
# 105093
# 105094
# 105095
# 105096
# 105097
# 105098
# 105099
# 105100
# 105101
# 105102
# 105103
# 105104
# 105105
# 105106
# 105107
# 105108
# 105109
# 105110
# 105111
# 105112
# 105113
# 105114
# 105115
# 105116
# 105117
# 105118
# 105119
# 105120
# 105121
# 105122
# 105123
# 105124
# 105125
# 105126
# 105127
# 105128
# 105129
# 105130
# 105131
# 105132
# 105133
# 105134
# 105135
# 105136
# 105137
# 105138
# 105139
# 105140
# 105141
# 105142
# 105143
# 105144
# 105145
# 105146
# 105147
# 105148
# 105149
# 105150
# 105151
# 105152
# 105153
# 105154
# 105155
# 105156
# 105157
# 105158
# 105159
# 105160
# 105161
# 105162
# 105163
# 105164
# 105165
# 105166
# 105167
# 105168
# 105169
# 105170
# 105171
# 105172
# 105173
# 105174
# 105175
# 105176
# 105177
# 105178
# 105179
# 105180
# 105181
# 105182
# 105183
# 105184
# 105185
# 106111
# 106112
# 106113
# 106114
# 106115
# 106116
# 106117
# 106118
# 106119
# 106120
# 106121
# 106122
# 106123
# 106124
# 106125
# 106126
# 106127
# 106128
# 106129
# 106130
# 106131
# 106132
# 106133
# 106134
# 106135
# 106136
# 106137
# 106138
# 106139
# 106140
# 106141
# 106142
# 106143
# 106144
# 106145
# 106146
# 106147
# 106148
# 106149
# 106150
# 106151
# 106152
# 106153
# 106154
# 106155
# 106156
# 106157
# 106158
# 106159
# 106160
# 106161
# 106162
# 106163
# 106164
# 106165
# 106166
# 106167
# 106168
# 106169
# 106170
# 106171
# 106172
# 106173
# 106174
# 106175
# 106176
# 106177
# 106178
# 106179
# 106180
# 106181
# 106182
# 106183
# 106184
# 106185
# 106186
# 106187
# 106188
# 106189
# 106190
# 106191
# 106192
# 106193
# 106194
# 106195
# 106196
# 106197
# 106198
# 106199
# 106200
# 106201
# 106202
# 106203
# 106204
# 106205
# 106206
# 106207
# 106208
# 106209
# 106210
# 106211
# 106212
# 106213
# 106214
# 106215
# 106216
# 106217
# 106218
# 106219
# 106220
# 106221
# 106222
# 106223
# 106224
# 106225
# 106226
# 106227
# 106228
# 106229
# 106230
# 106231
# 106232
# 106233
# 106234
# 106235
# 106236
# 106237
# 106238
# 106239
# 106240
# 106241
# 106242
# 106243
# 106244
# 106245
# 106246
# 106247
# 106248
# 106249
# 106250
# 106251
# 106252
# 106253
# 106254
# 106255
# 106256
# 106257
# 106258
# 106259
# 106260
# 106261
# 106262
# 106263
# 106264
# 106265
# 106266
# 106267
# 106268
# 106269
# 106270
# 106271
# 106272
# 106273
# 106274
# 106275
# 106276
# 106277
# 106278
# 106279
# 106280
# 106281
# 106282
# 106283
# 106284
# 106285
# 106286
# 106287
# 106288
# 106289
# 106290
# 106291
# 106292
# 106293
# 106294
# 106295
# 106296
# 106297
# 106298
# 106299
# 106300
# 106301
# 106302
# 106303
# 106304
# 106305
# 106306
# 106307
# 106308
# 106309
# 106310
# 106311
# 106312
# 106313
# 106314
# 106315
# 106316
# 106317
# 106318
# 106319
# 106320
# 106321
# 106322
# 106323
# 106324
# 106325
# 106326
# 106327
# 106328
# 106329
# 106330
# 106331
# 106332
# 106333
# 106334
# 106335
# 106336
# 106337
# 106338
# 106339
# 106340
# 106341
# 106342
# 106343
# 106344
# 106345
# 106346
# 106347
# 106348
# 106349
# 106350
# 106351
# 106352
# 106353
# 106354
# 106355
# 106356
# 106357
# 106358
# 106359
# 106360
# 106361
# 106362
# 106363
# 106364
# 106365
# 106366
# 106367
# 106368
# 106369
# 106370
# 106371
# 106372
# 106373
# 106374
# 106375
# 106376
# 106377
# 106378
# 106379
# 106380
# 106381
# 106382
# 106383
# 106384
# 106385
# 106386
# 106387
# 106388
# 106389
# 106390
# 106391
# 106392
# 106393
# 106394
# 106395
# 106396
# 106397
# 106398
# 106399
# 106400
# 106401
# 106402
# 106403
# 106404
# 106405
# 106406
# 106407
# 106408
# 106409
# 106410
# 106411
# 106412
# 106413
# 106414
# 106415
# 106416
# 106417
# 106418
# 106419
# 106420
# 106421
# 106422
# 106423
# 106424
# 106425
# 106426
# 106427
# 106428
# 106429
# 106430
# 106431
# 106432
# 106433
# 106434
# 106435
# 106436
# 106437
# 106438
# 106439
# 106440
# 106441
# 106442
# 106443
# 106444
# 106445
# 106446
# 106447
# 106448
# 106449
# 106450
# 106451
# 106452
# 106453
# 106454
# 106455
# 106456
# 106457
# 106458
# 106459
# 106460
# 106461
# 106462
# 106463
# 106464
# 106465
# 106466
# 106467
# 106468
# 106469
# 106470
# 106471
# 106472
# 106473
# 106474
# 106475
# 106476
# 106477
# 106478
# 106479
# 106480
# 106481
# 106482
# 106483
# 106484
# 106485
# 106486
# 106487
# 106488
# 106489
# 106490
# 106491
# 106492
# 106493
# 106494
# 106495
# 106496
# 106497
# 106498
# 106499
# 106500
# 106501
# 106502
# 106503
# 106504
# 106505
# 106506
# 106507
# 106508
# 106509
# 106510
# 106511
# 106512
# 106513
# 106514
# 106515
# 106516
# 106517
# 106518
# 106519
# 106520
# 106521
# 106522
# 106523
# 106524
# 106525
# 106526
# 106527
# 106528
# 106529
# 106530
# 106531
# 106532
# 106533
# 106534
# 106535
# 106536
# 106537
# 106538
# 106539
# 106540
# 106541
# 106542
# 106543
# 106544
# 106545
# 106546
# 106547
# 106548
# 106549
# 106550
# 106551
# 106552
# 106553
# 106554
# 106555
# 106556
# 106557
# 106558
# 106559
# 106560
# 106561
# 106562
# 106563
# 106564
# 106565
# 106566
# 106567
# 106568
# 106569
# 106570
# 106571
# 106572
# 106573
# 106574
# 106575
# 106576
# 106577
# 106578
# 106579
# 106580
# 106581
# 106582
# 106583
# 106584
# 106585
# 106586
# 106587
# 106588
# 106589
# 106590
# 106591
# 106592
# 106593
# 106594
# 106595
# 106596
# 106597
# 106598
# 106599
# 106600
# 106601
# 106602
# 106603
# 106604
# 106605
# 106606
# 106607
# 106608
# 106609
# 106610
# 106611
# 106612
# 106613
# 106614
# 106615
# 106616
# 106617
# 106618
# 106619
# 106620
# 106621
# 106622
# 106623
# 106624
# 106625
# 106626
# 106627
# 106628
# 106629
# 106630
# 106631
# 106632
# 106633
# 106634
# 106635
# 106636
# 106637
# 106638
# 106639
# 106640
# 106641
# 106642
# 106643
# 106644
# 106645
# 106646
# 106647
# 106648
# 106649
# 106650
# 106651
# 106652
# 106653
# 106654
# 106655
# 106656
# 106657
# 106658
# 106659
# 106660
# 106661
# 106662
# 106663
# 106664
# 106665
# 106666
# 106667
# 106668
# 106669
# 106670
# 106671
# 106672
# 106673
# 106674
# 106675
# 106676
# 106677
# 106678
# 106679
# 106680
# 106681
# 106682
# 106683
# 106684
# 106685
# 106686
# 106687
# 106688
# 106689
# 106690
# 106691
# 106692
# 106693
# 106694
# 106695
# 106696
# 106697
# 106698
# 106699
# 106700
# 106701
# 106702
# 106703
# 106704
# 106705
# 106706
# 106707
# 106708
# 106709
# 106710
# 106711
# 106712
# 106713
# 106714
# 106715
# 106716
# 106717
# 106718
# 106719
# 106720
# 106721
# 106722
# 106723
# 106724
# 106725
# 106726
# 109810
# 109811
# 109812
# 109813
# 109814
# 109815
# 109816
# 109817
# 109818
# 109819
# 109820
# 109821
# 109822
# 109823
# 109824
# 109825
# 109826
# 109827
# 109828
# 109829
# 109830
# 109831
# 109832
# 109833
# 109834
# 109835
# 109836
# 109837
# 109838
# 109839
# 109840
# 109841
# 109842
# 109843
# 109844
# 109845
# 109846
# 109847
# 109848
# 109849
# 109850
# 109851
# 109852
# 109853
# 109854
# 109855
# 109856
# 109857
# 109858
# 109859
# 109860
# 109861
# 109862
# 109863
# 109864
# 109865
# 109866
# 109867
# 109868
# 109869
# 109870
# 109871
# 109872
# 109873
# 109874
# 109875
# 109876
# 109877
# 109878
# 109879
# 109880
# 109881
# 109882
# 109883
# 109884
# 109885
# 109886
# 109887
# 109888
# 109889
# 109890
# 109891
# 109892
# 109893
# 109894
# 109895
# 109896
# 109897
# 109898
# 109899
# 109900
# 109901
# 109902
# 109903
# 109904
# 109905
# 109906
# 109907
# 109908
# 109909
# 109910
# 109911
# 109912
# 109913
# 109914
# 109915
# 109916
# 109917
# 109918
# 109919
# 109920
# 109921
# 109922
# 109923
# 109924
# 109925
# 109926
# 109927
# 109928
# 109929
# 109930
# 109931
# 109932
# 109933
# 109934
# 109935
# 109936
# 109937
# 109938
# 109939
# 109940
# 109941
# 109942
# 109943
# 109944
# 109945
# 109946
# 109947
# 109948
# 109949
# 109950
# 109951
# 109952
# 109953
# 109954
# 109955
# 109956
# 109957
# 109958
# 109959
# 109960
# 109961
# 109962
# 109963
# 109964
# 109965
# 109966
# 109967
# 109968
# 109969
# 109970
# 109971
# 109972
# 109973
# 109974
# 109975
# 109976
# 109977
# 109978
# 109979
# 109980
# 109981
# 109982
# 109983
# 109984
# 109985
# 109986
# 109987
# 109988
# 109989
# 109990
# 109991
# 109992
# 109993
# 109994
# 109995
# 109996
# 109997
# 109998
# 109999
# 110000

# %%
ride_count = 0
friends = []

for _ in range(3):
    friend = {"name": input("お友達の名前は？"), "height": int(input("お友達の身長は？"))}
    friends.append(friend)

    if friend["height"] >= 130:
        print(f"{friend['name']}くんは乗車できます")
        ride_count += 1
    else:
        print(f"{friend['name']}くんは乗車できません！")

print(f"乗車できるのは{ride_count}人です")
# Out:
# お友達の名前は？ああ
# お友達の身長は？１
# ああくんは乗車できません！
# お友達の名前は？いい
# お友達の身長は？１３０
# いいくんは乗車できます
# お友達の名前は？ううう
# お友達の身長は？１２９
# うううくんは乗車できません！
# 乗車できるのは1人です

# %%
ride_count = 0
friends = []

for i in range(3):
    friend = {}
    print("お友達の名前は？")
    friend['name']=input()
    print("お友達の身長は？")
    friend['height']=int(input())
    friends.append(friend)

for friend in friends:
    if friend['height']>=130:
        print(f"{friend['name']}くんは乗車できます")
        ride_count += 1
    else:
        print(f"{friend['name']}くんは乗車できません！")

print(f"乗車するのは{ride_count}人です")
# Out:
# お友達の名前は？
# ああ
# お友達の身長は？
# １３０
# お友達の名前は？
# いいい
# お友達の身長は？
# １２９
# お友達の名前は？
# １３０
# お友達の身長は？
# １３０
# ああくんは乗車できます
# いいいくんは乗車できません！
# １３０くんは乗車できます
# 乗車するのは2人です

# %%
# 関数の定義
def say_hello():
    print("Hello World")

# 関数の実行
say_hello()
# Out:
# Hello World

# %%
# 文字列の「Apple」ではなく数値の「5」が表示される
len("Apple")
# → 5
# Out:
# 5

# %%
# 関数の定義
def say_hello():
    print("Hello  World")

# 関数の実行
say_hello()
# Out:
# Hello  World

# %%
# 文字列の「Apple」ではなく数値の「5」が表示される
len("Ap   ple")
# → 5
# Out:
# 8

# %%
def sample():
    num = 2 * 3
    return num

print(sample())
# => 6
# Out:
# 6

# %%
def say_hello():
    print("Hello World")

# 関数の実行
say_hello()
# Out:
# Hello World

# %%
def plus_one():
    number = int(input())

plus_one()

print(number + 1)
# Out:
# １０
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-0ff8a903e1bc> in <cell line: 6>()
#       4 plus_one()
#       5
# ----> 6 print(number + 1)
#
# NameError: name 'number' is not defined

# %%
def square(number):  # ②仮引数numberで、実引数「3」の値を受け取る
    print(number * number)  # ③「3」が代入されたnumberを使って「3 * 3」を行い出力する

square(4)  # ①数値「3」を実引数にして関数を呼び出し
# Out:
# 16

# %%
def square(number):  # 仮引数はnumber」
    print(number * number)

number = 3

square(number)  # 実引数は「number」
# Out:
# 9

# %%
def mixer(fruit):
    print(f"{fruit}を細かく砕く")
    return(f"{fruit}ジュース")

print("フルーツを入力してください")
fruit = input()

print(mixer(fruit))
# Out:
# フルーツを入力してください
# りんご
# りんごを細かく砕く
# りんごジュース

# %%
for i in range(3):
    num = 1
    print(i+num)

print(num)

# 出力結果
1
2
3
1
# Out:
# 1
# 2
# 3
# 1
# 1

# %%
ride_count = 0

def add_friend(list):
    friend = {}
    print("お友達の名前は？")
    friend['name']=input()
    print("お友達の身長は？")
    friend['height']=int(input())
    list.append(friend)

friends = []

for i in range(3):
    add_friend(friends)

for friend in friends:
    if friend['height']>=130:
        print(f"{friend['name']}くんは乗車できます")
        ride_count += 1
    else:
        print(f"{friend['name']}くんは乗車できません！")

print(f"乗車できるのは{ride_count}人です")
# Out:
# お友達の名前は？
# ああ
# お友達の身長は？
# １３０
# お友達の名前は？
# いい
# お友達の身長は？
# １２９
# お友達の名前は？
# うう
# お友達の身長は？
# １３１
# ああくんは乗車できます
# いいくんは乗車できません！
# ううくんは乗車できます
# 乗車できるのは2人です

# %%
def judge_height(list):
    ride_count = 0

    for friend in list:
        if friend['height']>=130:
            print(f"{friend['name']}くんは乗車できます")
            ride_count += 1
        else:
            print(f"{friend['name']}くんは乗車できません！")
    print(f"乗車するのは{ride_count}人です")

def add_friend(list):
    friend = {}
    print("お友達の名前は？")
    friend['name']=input()
    print("お友達の身長は？")
    friend['height']=int(input())
    list.append(friend)

friends = []

for i in range(3):
    add_friend(friends)

judge_height(friends)
# Out:
# お友達の名前は？
# あああ
# お友達の身長は？
# １３０
# お友達の名前は？
# いいい
# お友達の身長は？
# １３０
# お友達の名前は？
# ううう
# お友達の身長は？
# １３０
# あああくんは乗車できます
# いいいくんは乗車できます
# うううくんは乗車できます
# 乗車するのは3人です
